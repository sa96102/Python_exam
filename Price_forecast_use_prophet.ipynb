# %% [markdown]
# <a href="https://colab.research.google.com/github/sa96102/Python_exam/blob/master/Price_forecast_use_prophet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
from fbprophet import Prophet

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Python_exam/Data/avocado.csv')

df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  ...          type  year  region
# 0           0  2015-12-27          1.33  ...  conventional  2015  Albany
# 1           1  2015-12-20          1.35  ...  conventional  2015  Albany
# 2           2  2015-12-13          0.93  ...  conventional  2015  Albany
# 3           3  2015-12-06          1.08  ...  conventional  2015  Albany
# 4           4  2015-11-29          1.28  ...  conventional  2015  Albany
#
# [5 rows x 14 columns]

# %%
df.describe() # 데이터셋의 대략적인 개요 출력.
# Out:
#          Unnamed: 0  AveragePrice  ...    XLarge Bags          year
# count  18249.000000  18249.000000  ...   18249.000000  18249.000000
# mean      24.232232      1.405978  ...    3106.426507   2016.147899
# std       15.481045      0.402677  ...   17692.894652      0.939938
# min        0.000000      0.440000  ...       0.000000   2015.000000
# 25%       10.000000      1.100000  ...       0.000000   2015.000000
# 50%       24.000000      1.370000  ...       0.000000   2016.000000
# 75%       38.000000      1.660000  ...     132.500000   2017.000000
# max       52.000000      3.250000  ...  551693.650000   2018.000000
#
# [8 rows x 11 columns]

# %% [markdown]
# ### Types

# %%
df.groupby('type').mean()
# Out:
#               Unnamed: 0  AveragePrice  ...  XLarge Bags         year
# type                                    ...
# conventional   24.236686      1.158040  ...  6210.635065  2016.147929
# organic        24.227776      1.653999  ...     1.197164  2016.147868
#
# [2 rows x 11 columns]

# %% [markdown]
# ### Preprocessing

# %%
df = df.loc[(df.type == 'conventional') & (df.region == 'TotalUS')]

df['Date'] = pd.to_datetime(df['Date'])

data = df[['Date', 'AveragePrice']].reset_index(drop=True)

data = data.rename(columns={'Date': 'ds', 'AveragePrice': 'y'})

data.head()
# Out:
#           ds     y
# 0 2015-12-27  0.95
# 1 2015-12-20  0.98
# 2 2015-12-13  0.93
# 3 2015-12-06  0.89
# 4 2015-11-29  0.99

# %%
data.plot(x='ds', y='y', figsize=(16, 8))

# %% [markdown]
# ### Prophet

# %%
model = Prophet()

model.fit(data) # 데이터 학습.
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# ### predict

# %%
future = model.make_future_dataframe(periods=365) # model.make_future_dataframe()_예측할 데이터를 정의.

forecast = model.predict(future) # model.predict()_미래 예측.

forecast.tail() # df.tail()_뒤에서 5개 출력.
# Out:
#             ds     trend  ...  multiplicative_terms_upper      yhat
# 529 2019-03-21  1.175446  ...                         0.0  1.116037
# 530 2019-03-22  1.175342  ...                         0.0  1.117355
# 531 2019-03-23  1.175237  ...                         0.0  1.119147
# 532 2019-03-24  1.175133  ...                         0.0  1.121399
# 533 2019-03-25  1.175029  ...                         0.0  1.124078
#
# [5 rows x 16 columns]

# %%
fig1 = model.plot(forecast)

# %% [markdown]
# ### Components

# %%
fig2 = model.plot_components(forecast) # model.plot_components()_예측에 영향을 준 요소를 출력.
